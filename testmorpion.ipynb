# %%
def place_libre(tabl, choix_pos, pos):                                                                             #verif place libre // renvoie True si la place est libre
    """_summary_

    Args:grille morpion, choix de la position par le joueur
        tabl (_type_): dic
        choix_pos (_type_): int[1-9]
    """
    
         
    if choix_pos in [7,8,9]:
        a=tabl['a'][pos]
        if isinstance(a,int):
            return True
        else:
            return False
            
    elif choix_pos in [4,5,6]:
        a=tabl['b'][pos]
        if isinstance(a, int):
            return True
        else:
            return False
        
        
    elif choix_pos in [1,2,3]:
        a=tabl['c'][pos]
        if isinstance(a, int):
            return True
        else:
            return False    

#trouver à l'afficher
def afficher_grille(tabl):                                                                                           #afficher grille
    """_summary_: permet d'afficher la grille morpion

    Args:
        tabl (dic): a besoin d'un dico à 3 clés "a,b et c">> contenant chacune une liste de 3 valeurs 
    En retour: affichage de la grille morpion
    """
    print ("{}|{}|{}".format(tabl['a'][0],tabl['a'][1],tabl['a'][2]))   
    print ("{}|{}|{}".format(tabl['b'][0],tabl['b'][1],tabl['b'][2])) 
    print ("{}|{}|{}".format(tabl['c'][0],tabl['c'][1],tabl['c'][2])) 




def grille_gagnante(grille):                                                                     #verif si grille est gagnante // Renvoi False si pas de grille gagnante
    """_summary_                                                                                                       

    Args:prend grille morpion paramétre
        tab (_type_): grille
        renvoi booléen(true: E  grille gagnante,false: pas de grille de gagnante)
    """
    if grille['a'][0]==grille['a'][1]==grille['a'][2]:
        return True
    elif grille['b'][0]==grille['b'][1]==grille['b'][2]:
        return True
    elif grille['c'][0]==grille['c'][1]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][0]==grille['c'][0]:
        return True
    elif grille['a'][1]==grille['b'][1]==grille['c'][1]:
        return True
    elif grille['a'][2]==grille['b'][2]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][1]==grille['c'][2]:
        return "1"
    elif grille['a'][2]==grille['b'][1]==grille['c'][0]:
        return "1"
    else:
        return "0"
    


def nul(tab):                                                                                                          #verif si match nul // renvoi False si pas de place libre
    """_summary_

    Args:
        tab (_type_): grille actualisée

    Returns:
        _type_: renvoie booléen pr savoir s'il y a match nul (aucune position dispo)
    """
    pos=0
    for i in range (1,10):
        if i in [1,4,7]:
            pos=0
        elif i in [2,5,8]:
            pos=1
        elif i in [3,6,9]:
            pos=2
            
        if place_libre(tab,i,pos):
        
            return True
            break
        else:
            return False
        
        
def choix_po():                                                                                        #à quelle place le joueur joue [1-9]
    """choix joueur position de jeu
    retour de la place [1-9] de la grille
    Returns:
        _type_: int
    """
    choix_pos_user=0
    
    while choix_pos_user not in [1,2,3,4,5,6,7,8,9]:
        choix_pos_user=int(input("sur quelle case libre tu veux jouer?(1-9!!!)"))
        pos=reafection_value(choix_pos_user) 
        if place_libre(grille,choix_pos_user,pos):
            pass
        else:
            choix_pos_user=0
    return choix_pos_user



def place_signe(tabl,signe,choix_pos,pos):                                                                             #placer signe X ou O (position voulue)
    """_summary_

    Args:
        tabl (_type_): grille
        signe (_type_): _X ou O
        choix_pos (_type_): position jr choisie pr jouer
        pos (_type_): translation choix_pos>pos pr compréhension dico
    """
    # if pos==3:
    #     pass
    
    if choix_pos in [7,8,9]:
        tabl['a'][pos]=signe
    elif choix_pos in [4,5,6]:
        tabl['b'][pos]=signe
    elif choix_pos in [1,2,3]:
        tabl['c'][pos]=signe    
    
    return tabl
        
        
def reafection_value(choix_pos):                                                                                     #reaffecte valeur // pr raccorder place chiffre à valeur indice du dico
    """_
    reaffecte le choix de position à une valeur utilisable pour placer dans la grille via dictionnaire
    Args:le choix de la position du joueur [1-9]
        choix (_type_): _de
    """
    
    
    if choix_pos in [1,4,7]:
        pos=0
    elif choix_pos in [2,5,8]:
        pos=1
    elif choix_pos in [3,6,9]:
        pos=2
    else:
        pos=2
    return pos
   
def a_qui(tour):                                                                                                      # alternance des tours
    """_summary_

    Args:
        tour (_type_): numéro du tour

    Returns:
        _type_: renvoi booléen: permet ensuitre de savoir quel signe et quel joueur joue
    """
    if tour%2==0:
        return True
    else:
        return False
# Out:
# O

# %%
def grille_gagnante(grille):                                                                     #verif si grille est gagnante // Renvoi False si pas de grille gagnante
    """_summary_                                                                                                       

    Args:prend grille morpion paramétre
        tab (_type_): grille
        renvoi booléen(true: E  grille gagnante,false: pas de grille de gagnante)
    """
    if grille['a'][0]==grille['a'][1]==grille['a'][2]:
        return True
    elif grille['b'][0]==grille['b'][1]==grille['b'][2]:
        return True
    elif grille['c'][0]==grille['c'][1]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][0]==grille['c'][0]:
        return True
    elif grille['a'][1]==grille['b'][1]==grille['c'][1]:
        return True
    elif grille['a'][2]==grille['b'][2]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][1]==grille['c'][2]:
        return "1"
    elif grille['a'][2]==grille['b'][1]==grille['c'][0]:
        return "1"
    else:
        return "0"

# %%
def place_libre(tabl, choix_pos, pos):                                                                             #verif place libre // renvoie True si la place est libre
    """_summary_

    Args:grille morpion, choix de la position par le joueur
        tabl (_type_): dic
        choix_pos (_type_): int[1-9]
    """
    
         
    if choix_pos in [7,8,9]:
        a=tabl['a'][pos]
        if isinstance(a,int):
            return True
        else:
            return False
            
    elif choix_pos in [4,5,6]:
        a=tabl['b'][pos]
        if isinstance(a, int):
            return True
        else:
            return False
        
        
    elif choix_pos in [1,2,3]:
        a=tabl['c'][pos]
        if isinstance(a, int):
            return True
        else:
            return False    

#trouver à l'afficher
def afficher_grille(tabl):                                                                                           #afficher grille
    """_summary_: permet d'afficher la grille morpion

    Args:
        tabl (dic): a besoin d'un dico à 3 clés "a,b et c">> contenant chacune une liste de 3 valeurs 
    En retour: affichage de la grille morpion
    """
    print ("{}|{}|{}".format(tabl['a'][0],tabl['a'][1],tabl['a'][2]))   
    print ("{}|{}|{}".format(tabl['b'][0],tabl['b'][1],tabl['b'][2])) 
    print ("{}|{}|{}".format(tabl['c'][0],tabl['c'][1],tabl['c'][2])) 




def grille_gagnante(grille):                                                                     #verif si grille est gagnante // Renvoi False si pas de grille gagnante
    """_summary_                                                                                                       

    Args:prend grille morpion paramétre
        tab (_type_): grille
        renvoi booléen(true: E  grille gagnante,false: pas de grille de gagnante)
    """
    if grille['a'][0]==grille['a'][1]==grille['a'][2]:
        return True
    elif grille['b'][0]==grille['b'][1]==grille['b'][2]:
        return True
    elif grille['c'][0]==grille['c'][1]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][0]==grille['c'][0]:
        return True
    elif grille['a'][1]==grille['b'][1]==grille['c'][1]:
        return True
    elif grille['a'][2]==grille['b'][2]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][1]==grille['c'][2]:
        return "1"
    elif grille['a'][2]==grille['b'][1]==grille['c'][0]:
        return "1"
    else:
        return "0"
    


def nul(tab):                                                                                                          #verif si match nul // renvoi False si pas de place libre
    """_summary_

    Args:
        tab (_type_): grille actualisée

    Returns:
        _type_: renvoie booléen pr savoir s'il y a match nul (aucune position dispo)
    """
    pos=0
    for i in range (1,10):
        if i in [1,4,7]:
            pos=0
        elif i in [2,5,8]:
            pos=1
        elif i in [3,6,9]:
            pos=2
            
        if place_libre(tab,i,pos):
        
            return True
            break
        else:
            return False
        
        
def choix_po():                                                                                        #à quelle place le joueur joue [1-9]
    """choix joueur position de jeu
    retour de la place [1-9] de la grille
    Returns:
        _type_: int
    """
    choix_pos_user=0
    
    while choix_pos_user not in [1,2,3,4,5,6,7,8,9]:
        choix_pos_user=int(input("sur quelle case libre tu veux jouer?(1-9!!!)"))
        pos=reafection_value(choix_pos_user) 
        if place_libre(grille,choix_pos_user,pos):
            pass
        else:
            choix_pos_user=0
    return choix_pos_user



def place_signe(tabl,signe,choix_pos,pos):                                                                             #placer signe X ou O (position voulue)
    """_summary_

    Args:
        tabl (_type_): grille
        signe (_type_): _X ou O
        choix_pos (_type_): position jr choisie pr jouer
        pos (_type_): translation choix_pos>pos pr compréhension dico
    """
    # if pos==3:
    #     pass
    
    if choix_pos in [7,8,9]:
        tabl['a'][pos]=signe
    elif choix_pos in [4,5,6]:
        tabl['b'][pos]=signe
    elif choix_pos in [1,2,3]:
        tabl['c'][pos]=signe    
    
    return tabl
        
        
def reafection_value(choix_pos):                                                                                     #reaffecte valeur // pr raccorder place chiffre à valeur indice du dico
    """_
    reaffecte le choix de position à une valeur utilisable pour placer dans la grille via dictionnaire
    Args:le choix de la position du joueur [1-9]
        choix (_type_): _de
    """
    
    
    if choix_pos in [1,4,7]:
        pos=0
    elif choix_pos in [2,5,8]:
        pos=1
    elif choix_pos in [3,6,9]:
        pos=2
    else:
        pos=2
    return pos
   
def a_qui(tour):                                                                                                      # alternance des tours
    """_summary_

    Args:
        tour (_type_): numéro du tour

    Returns:
        _type_: renvoi booléen: permet ensuitre de savoir quel signe et quel joueur joue
    """
    if tour%2==0:
        return True
    else:
        return False
# Out:
# O

# %%
def reafection_value(choix_pos):                                                                                     #reaffecte valeur
    """_
    reaffecte le choix de position à une valeur utilisable pour placer dans la grille via dictionnaire
    Args:le choix de la position du joueur [1-9]
        choix (_type_): _de
    """
    
    
    if choix_pos in [1,4,7]:
        pos=0
    elif choix_pos in [2,5,8]:
        pos=1
    elif choix_pos in [3,6,9]:
        pos=2
    return pos

reafection_value(6)
# Out:
# 2

# %%
tour=0
grille= {
    'a': [7,8,9],
    'b': [4,5,6],
    'c': [1,2,3]
}

def morpion(grille,tour):
    while nul(grille) or grille_gagnante(grille):
        if a_qui(tour):                                                                                #alternance de tour
            signe="X" 
        else:
            signe="O"  

        if signe=='X':
            joueur_actu="joueur_1"
            print("au joueur 1 de jouer")
        elif signe=='O':
            joueur_actu="joueur_2"
            print("au joueur 2 de jouer")
    
        afficher_grille(grille)
        
        choix_pos=choix_po()                                                                          #retourne choix de position entre 1 et 10
                
        pos=reafection_value(choix_pos)                                                              #reaffection de la valeur

        place_signe(grille,signe,choix_pos,pos)                                                      #place le signe du joueur à la position X voulue
        grille=place_signe(grille,signe,choix_pos,pos)
        # afficher_grille(grille)
        
        if grille_gagnante(grille)==1:                                                               #verif si une grille est gagnante
            print(f"le {joueur_actu}a gagné")
            break
        else:
            pass

        if nul(grille):                                                                             #verifie si la grille est nulle(aucune position libre) 
            pass
        else:                                                 
            print("la partie est en match nul !")
        tour+=1   
          
    # print("bonne partie!")
morpion(grille,tour)
# Out:
# au joueur 1 de jouer
# 7|8|9
# 4|5|6
# 1|2|3
# au joueur 2 de jouer
# 7|8|9
# 4|X|6
# 1|2|3
# au joueur 1 de jouer
# 7|8|9
# 4|X|6
# O|2|3
# au joueur 2 de jouer
# 7|8|X
# 4|X|6
# O|2|3
# au joueur 1 de jouer
# 7|8|X
# 4|X|6
# O|2|O
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 45
#      42         tour+=1
#      44     # print("bonne partie!")
# ---> 45 morpion(grille,tour)
#
# Cell In[35], line 24, in morpion(grille, tour)
#      20     print("au joueur 2 de jouer")
#      22 afficher_grille(grille)
# ---> 24 choix_pos=choix_po()                                                                          #retourne choix de position entre 1 et 10
#      26 pos=reafection_value(choix_pos)                                                              #reaffection de la valeur
#      28 place_signe(grille,signe,choix_pos,pos)                                                      #place le signe du joueur à la position X voulue
#
# Cell In[18], line 111, in choix_po()
#     108 choix_pos_user=0
#     110 while choix_pos_user not in [1,2,3,4,5,6,7,8,9]:
# --> 111     choix_pos_user=int(input("sur quelle case libre tu veux jouer?(1-9!!!)"))
#     112     pos=reafection_value(choix_pos_user)
#     113     if place_libre(grille,choix_pos_user,pos):
#
# ValueError: invalid literal for int() with base 10: ''

# %%
morpion()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 morpion()
#
# Cell In[22], line 10, in morpion()
#       9 def morpion():
# ---> 10         while nul(grille) or grille_gagnante(grille):
#      11             if a_qui(tour):                                                                                #alternance de tour
#      12                 signe="X"
#
# UnboundLocalError: local variable 'grille' referenced before assignment

# %%
if a_qui(tour):
    signe="X" 
else:
    signe="O"  

if signe=='X':
    joueur_actu="joueur_1"
    print("au joueur 1 de jouer, allez!")
elif signe=='O':
    joueur_actu="joueur_2"
    print("au joueur 2 de jouer, allez!")
    
afficher_grille(grille)
choix=choix_po()                                                                            #retourne choix de position entre 1 et 10
pos=reafection_value(choix) 
print(pos)
# Out:
# au joueur 2 de jouer, allez!
# X|8|9
# X|5|6
# X|2|3
# 0

# %%
grille={                                                                      #grille gagnante??
    'a': [8,8,8],
    'b': [4,5,6],
    'c': [1,2,3]


}

def grille_gagnante(tab):
    """_summary_

    Args:prend grille morpion paramétre
        tab (_type_): grille
        renvoi booléen(True: E  grille gagnante,False: pas de grille de gagnante)
    """
    if grille['a'][0]==grille['a'][1]==grille['a'][2]:
        return True
    elif grille['b'][0]==grille['b'][1]==grille['b'][2]:
        return True
    elif grille['c'][0]==grille['c'][1]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][0]==grille['c'][0]:
        return True
    elif grille['a'][1]==grille['b'][1]==grille['c'][1]:
        return True
    elif grille['a'][2]==grille['b'][2]==grille['c'][2]:
        return True
    elif grille['a'][0]==grille['b'][1]==grille['c'][2]:
        return True
    elif grille['a'][2]==grille['b'][1]==grille['c'][0]:
        return True
    else:
        return False
    
grille_gagnante(grille)

# %%
X=type(str)
O=type(str)


grille={                                                                      #grille gagnante??
    'a': [X,X,X],
    'b': [O,8,X],
    'c': [O,O,X]

}    


# def nul (tab):
#     for i in [[tab['a']],tab['b'],tab['c']]:
#         for j in [0,1,2]:
#             if j in range (1,10):
#                 return True 
        

def place_libre(tab, choix_pos, pos):                                                                             #verif place libre // renvoie True si la place est libre
    """_summary_

    Args:grille morpion, choix de la position par le joueur
        tabl (_type_): dic
        choix_pos (_type_): int[1-9]
    """
    
         
    if choix_pos in [7,8,9]:
        a=tab['a'][pos]
        if isinstance(a,int):
            return True
        else:
            return False
            
    elif choix_pos in [4,5,6]:
        a=tab['b'][pos]
        if isinstance(a, int):
            return True
        else:
            return False
        
        
    elif choix_pos in [1,2,3]:
        a=tab['c'][pos]
        if isinstance(a, int):
            return True
        else:
            return False    

def nul(tab):                                                                                                          #verif si match nul // renvoi False si pas de place libre
    """_summary_

    Args:
        tab (_type_): grille (actualisée)

    Returns:
        _type_: renvoie booléen pr savoir s'il y a match nul (aucune position dispo)
    """
    
    for i in range (1,10):
        if i in [1,4,7]:
            pos=0
        elif i in [2,5,8]:
            pos=1
        elif i in [3,6,9]:
            pos=2
            
        if place_libre(tab,i,pos):       
            return True
        else:
            return False

nul(grille)
# Out:
# False

# %%
grille={                                                                      #grille gagnante??
    'a': [X,X,X],
    'b': [O,8,X],
    'c': [O,O,X]

}    


def nul (tab):
    a=[0]
    for i in [[tab['a']],tab['b'],tab['c']]:
        for j in [0,1,2]:
            a=tab[i][j] 
            if isinstance(a,int):
                a.append(1)
                
    print(a)
    # if '1' in a:
    #     return True
    # else: 
    #     return False 
                
nul(grille)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 23
#      17     print(a)
#      18     # if '1' in a:
#      19     #     return True
#      20     # else:
#      21     #     return False
# ---> 23 nul(grille)
#
# Cell In[56], line 13, in nul(tab)
#      11 for i in [[tab['a']],tab['b'],tab['c']]:
#      12     for j in [0,1,2]:
# ---> 13         a=tab[i][j]
#      14         if isinstance(a,int):
#      15             a.append(1)
#
# TypeError: unhashable type: 'list'

# %%
a=[1,3,5]

# %%
choix_pos=choix_po()                                                                         #retourne choix de position entre 1 et 10
pos=reafection_value(choix_pos)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 choix_pos=choix_po()                                                                         #retourne choix de position entre 1 et 10
# ----> 2 pos=reafection_value(choix_pos)
#
# Cell In[18], line 150, in reafection_value(choix_pos)
#     148 elif choix_pos in [3,6,9]:
#     149     pos=2
# --> 150 return pos
#
# UnboundLocalError: local variable 'pos' referenced before assignment

# %%
grille={                                                                      #grille gagnante??
    'a': [X,X,X],
    'b': [O,8,X],
    'c': [O,O,X]

}

d=grille[b][1]
print(d)
isinstance(d, int)
# Out:
# 8
# True

# %%
a= 9
if a in range (1,10):
    print("super")
# Out:
# super

# %%
grille={                                                                      #grille gagnante??
    'a': [X,X,X],
    'b': [O,8,X],
    'c': [O,O,X]

}   
a=[]

if grille['b'][1] in range (1,10):
    a.append(1) 
else:
    print("pinochio")
    
print(a)
if 1 in range(10):
    print("elsa")
# Out:
# [1]
# elsa

# %%
grille= {
    'a': [7,8,9],
    'b': [4,5,6],
    'c': [1,2,3]
}

def match_nul(grille):
    for keys, values in grille.items():
        a=[]
        for i in values :
           a.append(i)
    for i in a:
        for j in range (2):
            a[i][j]
            
            
            
match_nul(grille)
# Out:
# [7, 8, 9]
# [4, 5, 6]
# [1, 2, 3]
